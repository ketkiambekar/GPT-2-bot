# %% [markdown]
# #Twitter Authentication

# %%
import tweepy

# %%
ACCESS_TOKEN="1272934092506648576-zxa4sA5OzJtdH84M8bOsD8qKOlSqTn"
ACCESS_TOKEN_SECRET="J4sDxBl4p8QOALv9jNMXAcIeFdj3anFfDw3WfAZTGmQYL"
CONSUMER_KEY="dj6TonEZtwxb1vpGSgcwkIPkt"
CONSUMER_SECRET="mex9vGQaskrwgBXktbyRK4n7R9dx4zmW4971PE8fer55QfmkBz"

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# Authenticate to Twitter
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# Create API object
api = tweepy.API(auth)

# %%
api.update_status("Hello World")
# Out:
# Status(_api=<tweepy.api.API object at 0x7f310c45d940>, _json={'created_at': 'Tue Aug 11 11:13:55 +0000 2020', 'id': 1293143606719590400, 'id_str': '1293143606719590400', 'text': 'Hello World', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://resilience2032.com" rel="nofollow">AIR_API</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1272934092506648576, 'id_str': '1272934092506648576', 'name': 'ResilienceAI', 'screen_name': 'AiResilience', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Tue Jun 16 16:48:46 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, '
# ...
